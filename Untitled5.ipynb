# %%
import bs4

# %%
import requests

# %%
import pandas as pd

# %%
import re

# %%
#참고
# https://nbviewer.org/gist/FinanceData/35a1b0d5248bc9b09513e53be437ac42

# %%
res = requests.get("https://www.marketwatch.com/investing/stock/aapl/financials/income/quarter")

# %%
res.text
# Out:
# '\n\n\n<!DOCTYPE html>\n<html class="" lang="en">\n<head>\n        <title>AAPL | Apple Inc. Quarterly Income Statement | MarketWatch</title>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="user-scalable=no, initial-scale=1.0, maximum-scale=1.0, width=device-width">\n            <meta name="robots" content="noarchive, noodp">\n\n\n<link rel="dns-prefetch" href="//sts.wsj.net" />\n<link rel="dns-prefetch" href="//s.marketwatch.com" />\n<link rel="dns-prefetch" href="//video-api.wsj.com" />\n<link rel="dns-prefetch" href="//fonts.wsj.net" />\n<link rel="dns-prefetch" href="//m.wsj.net" />\n<link rel="dns-prefetch" href="//mwstream.wsj.net" />\n<link rel="dns-prefetch" href="//tags.tiqcdn.com" />\n<link rel="dns-prefetch" href="//s.ntv.io" />\n<link rel="dns-prefetch" href="//cdn.cxense.com" />\n<link rel="dns-prefetch" href="//a248.e.akamai.net" />\n<link rel="dns-prefetch" href="//om.dowjoneson.com" 
# ...

# %%
df_list = pd.read_html(res.text) # tabl형태로 가져올때는 read_html

# %%
len(df_list)
# Out:
# 5

# %%
df = df_list[4]

# %%
df.head()
# Out:
#                                           Item  Item 31-Mar-2022 30-Jun-2022  \
# 0                       Sales/Revenue  Sales/Revenue      97.28B      82.96B
# 1                         Sales Growth  Sales Growth           -     -14.72%
# 2  Cost of Goods Sold (COGS) incl. D&A  Cost of G...      54.72B      47.07B
# 3                           COGS Growth  COGS Growth           -     -13.97%
# 4             COGS excluding D&A  COGS excluding D&A      51.98B      44.27B
#
#   30-Sep-2022 31-Dec-2022 31-Mar-2023  5- qtr trend
# 0      90.15B     117.15B      94.84B           NaN
# 1       8.66%      29.96%     -19.05%           NaN
# 2      52.05B      66.82B      52.86B           NaN
# 3      10.57%      28.38%     -20.89%           NaN
# 4      49.19B      63.91B      49.96B           NaN

# %%
df.columns
# Out:
# Index(['Item  Item', '31-Mar-2022', '30-Jun-2022', '30-Sep-2022',
#        '31-Dec-2022', '31-Mar-2023', '5- qtr trend'],
#       dtype='object')

# %%
b = df.iloc[0]

# %%
b['Item  Item']
# Out:
# 'Sales/Revenue  Sales/Revenue'
